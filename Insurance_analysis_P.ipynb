# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Insurance Data Analysis

# %%
data = pd.read_csv('insurance.csv')

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#let's review the shape of the data

# %%
data.shape
# Out:
# (1338, 7)

# %%
# checking the missing values in the data frame

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#let's checl count of male and female first

# %%
sex_count = data['sex'].value_counts()

# %%
sex_count
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
#Plotting the feature column on count plot

# %%
a = data[['sex','smoker','region']]

# %%
a
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
for col in a:
    plt.figure(figsize=(5,5))
    sns.countplot(x=col,hue = 'sex',data=a)
    plt.title(f'Count Plot for {col}')
    plt.show()

# %%
#plotting a scatter plot of numerical columns

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x= 'charges',y='bmi',hue = 'sex',data=data)
plt.show()

# %%
sns.pairplot(data[['age', 'bmi', 'children', 'charges']])
plt.title("Pair Plot: Age, BMI, Children, Charges")
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# premium charges of smokers and non-smokers as per the age

# %%
sns.lineplot(x='age', y='charges', hue='smoker', data=data)
plt.title("Premium Charges vs Age (Smoker vs Non-Smoker)")
plt.show()

# %%
# the above oberservation reflects that the premium charges for smoker are increasing as they getting old than
# non-smokers.
